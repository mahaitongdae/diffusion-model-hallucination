# %%
from inspect_results import load_best_results, load_full_results
import numpy as np
import pandas as pd
import os

import sys
sys.path.append('/home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/gaussian_experiments/utils')
from inspect_results import load_best_results, load_full_results
import matplotlib.pyplot as plt

# %%
def get_max_regret(energy_fn):
    x = np.linspace(-10, 10, 1000)
    y = energy_fn(x)
    return np.max(y)

from energy_funcs import EnergyFunctionsRegistry

x = np.linspace(-6, 6, 1000)
energy_fn = EnergyFunctionsRegistry.get("energy_func_log_two_gaussian")
plt.plot(x, energy_fn(x))
plt.show()
max_reward = get_max_regret(energy_fn)
print("max reward: ", max_reward)
# Out:
# max reward:  -0.2231604727754877

# %%
def get_max_regret(energy_fn):
    x = np.linspace(-10, 10, 1000)
    y = energy_fn(x)
    return np.max(y)

from energy_funcs import EnergyFunctionsRegistry

x = np.linspace(-6, 6, 1000)
energy_fn = EnergyFunctionsRegistry.get("energy_func_two_gaussian")
plt.plot(x, energy_fn(x, l=0.1))
plt.show()
max_rewards = {}
for l in [0.1, 0.2, 0.3]:
    max_reward = get_max_regret(lambda x: energy_fn(x, l=l))
    print("max reward at l: ", l, "is: ", max_reward)
    max_rewards[l] = max_reward
# Out:
# max reward at l:  0.1 is:  0.6965715531030394
# max reward at l:  0.2 is:  0.6991413095332641
# max reward at l:  0.3 is:  0.6996182296658089

# %%
all_results_df = []
logdir = '/home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval'
# for weight_pre_transform_fn in ["substract_min", "standarize-relu", "standarize-substract_min"]:
for weights_transform_fn in ["relu_normalize", "quad_relu_normalize", "softmax"]:
    for initial_mean in [0.0, 1.0, 2.0]:
        pattern = fr".*reweighting_rl.*w{weights_transform_fn}.*im{initial_mean}.*$"
        df = load_full_results(pattern, logdir=logdir)
        if df is not None:
            print(df.head())
            df['initial_mean'] = initial_mean
            df['weights_transform_fn'] = weights_transform_fn
            df['noise'] = 0.05
            all_results_df.append(df)
all_results_df_sweep_initial_noise_scale = pd.concat(all_results_df)
all_results_df_sweep_initial_noise_scale['regret'] = max_reward - all_results_df_sweep_initial_noise_scale['energy_mean']
all_results_df_sweep_initial_noise_scale['epoch'] = all_results_df_sweep_initial_noise_scale['epoch'] - 300
# Out:
# $-0.293 \pm 0.307$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300    -2.206129    0.944149       0.009330
# 1    302    -1.374398    0.812157       0.008026
# 2    304    -0.481785    0.365342       0.003610
# 3    306    -0.279701    0.088866       0.000878
# 4    308    -0.238380    0.023448       0.000232
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $-0.277 \pm 0.245$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300    -1.859240    0.640030       0.006325
# 1    302    -0.989655    0.765403       0.007564
# 2    304    -0.397355    0.259970       0.002569
# 3    306    -0.263631    0.063177       0.000624
# 4    308    -0.237503    0.021577       0.000213
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $-0.258 \pm 0.156$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300    -1.304277    0.831343       0.008215
# 1    302    -0.620660    0.524758       0.005186
# 2    304    -0.312836    0.134606       0.001330
# 3    306    -0.251124    0.042122       0.000416
# 4    308    -0.235962    0.019219       0.000190
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $-0.288 \pm 0.303$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300    -2.206129    0.944149       0.009330
# 1    302    -1.320951    0.828384       0.008186
# 2    304    -0.445453    0.325022       0.003212
# 3    306    -0.261798    0.060801       0.000601
# 4    308    -0.232532    0.014458       0.000143
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $-0.276 \pm 0.247$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300    -1.858792    0.626350       0.006190
# 1    302    -0.988479    0.767033       0.007580
# 2    304    -0.401137    0.266087       0.002630
# 3    306    -0.267428    0.069890       0.000691
# 4    308    -0.233972    0.016568       0.000164
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $-0.256 \pm 0.156$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300    -1.281494    0.819035       0.008094
# 1    302    -0.629834    0.543286       0.005369
# 2    304    -0.311765    0.134104       0.001325
# 3    306    -0.245445    0.033620       0.000332
# 4    308    -0.230699    0.011018       0.000109
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $-inf \pm nan$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300    -2.191158    0.921674       0.009108
# 1    302    -1.337240    1.062964       0.010504
# 2    304    -0.578003    0.489274       0.004835
# 3    306    -0.303475    0.123976       0.001225
# 4    308    -0.243801    0.031421       0.000311
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $-0.279 \pm 0.247$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300    -1.859240    0.640030       0.006325
# 1    302    -1.043702    0.791934       0.007826
# 2    304    -0.437658    0.312712       0.003090
# 3    306    -0.273331    0.078789       0.000779
# 4    308    -0.238209    0.022379       0.000221
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $-0.259 \pm 0.156$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300    -1.293600    0.839068       0.008292
# 1    302    -0.646894    0.552384       0.005459
# 2    304    -0.322232    0.145875       0.001442
# 3    306    -0.257177    0.051011       0.000504
# 4    308    -0.235391    0.018098       0.000179
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# /home/naliseas-workstation/anaconda3/envs/haitong_botorch/lib/python3.9/site-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_context('paper', font_scale=1.2)
for initial_mean in all_results_df_sweep_initial_noise_scale['initial_mean'].unique():
    df = all_results_df_sweep_initial_noise_scale[all_results_df_sweep_initial_noise_scale['initial_mean'] == initial_mean].reset_index(drop=True)
    print(df.head().to_markdown())
    fig, ax = plt.subplots(1, 1, figsize=(3, 3))
    sns.lineplot(x='epoch', y='regret', data=df, hue='weights_transform_fn', ax=ax)
    h, l = ax.get_legend_handles_labels()
    ax.legend(h, ['identity', 'quadratic', 'softmax'], title='Weights')
    ax.set_yscale('log')
    ax.set_title(f'Initial mean: {initial_mean}')
    plt.tight_layout()
    plt.savefig(f'regret_plot_log_energy_im{initial_mean}.pdf', dpi=300)
# Out:
# |    |   epoch |   energy_mean |   energy_std |   energy_stderr | logdir                                                                                                                                                                                                                   |   initial_mean | weights_transform_fn   |   noise |    regret |
# |---:|--------:|--------------:|-------------:|----------------:|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------:|:-----------------------|--------:|----------:|
# |  0 |       0 |     -2.20613  |    0.944149  |     0.00933019  | /home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval/20260125_145357_reweighting_rl_seed_44_add_noise_0.05_temp_0.1_s44_wrelu_normalize_im0.0_t0.1_relu_normalize |              0 | relu_normalize         |    0.05 | 1.98297   |
# |  1 |       2 |     -1.3744   |    0.812157  |     0.00802583  | /home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval/20260125_145357_reweighting_rl_seed_44_add_noise_0.05_temp_0.1_s44_wrelu_normalize_im0.0_t0.1_relu_normalize |              0 | relu_normalize         |    0.05 | 1.15124   |
# |  2 |       4 |     -0.481785 |    0.365342  |     0.00361035  | /home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval/20260125_145357_reweighting_rl_seed_44_add_noise_0.05_temp_0.1_s44_wrelu_normalize_im0.0_t0.1_relu_normalize |              0 | relu_normalize         |    0.05 | 0.258625  |
# |  3 |       6 |     -0.279701 |    0.088866  |     0.000878184 | /home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval/20260125_145357_reweighting_rl_seed_44_add_noise_0.05_temp_0.1_s44_wrelu_normalize_im0.0_t0.1_relu_normalize |              0 | relu_normalize         |    0.05 | 0.0565401 |
# |  4 |       8 |     -0.23838  |    0.0234485 |     0.000231721 | /home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval/20260125_145357_reweighting_rl_seed_44_add_noise_0.05_temp_0.1_s44_wrelu_normalize_im0.0_t0.1_relu_normalize |              0 | relu_normalize         |    0.05 | 0.0152199 |
# |    |   epoch |   energy_mean |   energy_std |   energy_stderr | logdir                                                                                                                                                                                                                   |   initial_mean | weights_transform_fn   |   noise |    regret |
# |---:|--------:|--------------:|-------------:|----------------:|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------:|:-----------------------|--------:|----------:|
# |  0 |       0 |     -1.85924  |    0.64003   |     0.00632485  | /home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval/20260125_144723_reweighting_rl_seed_44_add_noise_0.05_temp_0.1_s44_wrelu_normalize_im1.0_t0.1_relu_normalize |              1 | relu_normalize         |    0.05 | 1.63608   |
# |  1 |       2 |     -0.989655 |    0.765403  |     0.0075638   | /home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval/20260125_144723_reweighting_rl_seed_44_add_noise_0.05_temp_0.1_s44_wrelu_normalize_im1.0_t0.1_relu_normalize |              1 | relu_normalize         |    0.05 | 0.766495  |
# |  2 |       4 |     -0.397355 |    0.25997   |     0.00256906  | /home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval/20260125_144723_reweighting_rl_seed_44_add_noise_0.05_temp_0.1_s44_wrelu_normalize_im1.0_t0.1_relu_normalize |              1 | relu_normalize         |    0.05 | 0.174195  |
# |  3 |       6 |     -0.263631 |    0.0631772 |     0.000624324 | /home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval/20260125_144723_reweighting_rl_seed_44_add_noise_0.05_temp_0.1_s44_wrelu_normalize_im1.0_t0.1_relu_normalize |              1 | relu_normalize         |    0.05 | 0.0404709 |
# |  4 |       8 |     -0.237503 |    0.0215769 |     0.000213226 | /home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval/20260125_144723_reweighting_rl_seed_44_add_noise_0.05_temp_0.1_s44_wrelu_normalize_im1.0_t0.1_relu_normalize |              1 | relu_normalize         |    0.05 | 0.0143429 |
# |    |   epoch |   energy_mean |   energy_std |   energy_stderr | logdir                                                                                                                                                                                                                   |   initial_mean | weights_transform_fn   |   noise |    regret |
# |---:|--------:|--------------:|-------------:|----------------:|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------:|:-----------------------|--------:|----------:|
# |  0 |       0 |     -1.30428  |    0.831343  |     0.00821543  | /home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval/20260125_145608_reweighting_rl_seed_42_add_noise_0.05_temp_0.1_s42_wrelu_normalize_im2.0_t0.1_relu_normalize |              2 | relu_normalize         |    0.05 | 1.08112   |
# |  1 |       2 |     -0.62066  |    0.524758  |     0.00518572  | /home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval/20260125_145608_reweighting_rl_seed_42_add_noise_0.05_temp_0.1_s42_wrelu_normalize_im2.0_t0.1_relu_normalize |              2 | relu_normalize         |    0.05 | 0.397499  |
# |  2 |       4 |     -0.312836 |    0.134606  |     0.00133019  | /home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval/20260125_145608_reweighting_rl_seed_42_add_noise_0.05_temp_0.1_s42_wrelu_normalize_im2.0_t0.1_relu_normalize |              2 | relu_normalize         |    0.05 | 0.0896756 |
# |  3 |       6 |     -0.251124 |    0.0421222 |     0.000416256 | /home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval/20260125_145608_reweighting_rl_seed_42_add_noise_0.05_temp_0.1_s42_wrelu_normalize_im2.0_t0.1_relu_normalize |              2 | relu_normalize         |    0.05 | 0.0279637 |
# |  4 |       8 |     -0.235962 |    0.0192194 |     0.000189929 | /home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_log_eng_fix_eval/20260125_145608_reweighting_rl_seed_42_add_noise_0.05_temp_0.1_s42_wrelu_normalize_im2.0_t0.1_relu_normalize |              2 | relu_normalize         |    0.05 | 0.0128014 |

# %%
all_results_df = []
l = 0.1
logdir = '/home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/20260125_two_gaussian_small_l_fixed_eval'
# for weight_pre_transform_fn in ["substract_min", "standarize-relu", "standarize-substract_min"]:
for weights_transform_fn in ["relu_normalize", "quad_relu_normalize", "softmax"]:
    for initial_mean in [0.0, 1.0, 2.0]:
        for l in [0.1, 0.2, 0.3]:
            pattern = fr".*reweighting_rl.*w{weights_transform_fn}.*im{initial_mean}.*l{l}.*$"
            df = load_full_results(pattern, logdir=logdir)
            if df is not None:
                print(df.head())
                df['initial_mean'] = initial_mean
                df['weights_transform_fn'] = weights_transform_fn
                df['noise'] = 0.05
                df['l'] = l
                df['regret'] = max_rewards[l] - df['energy_mean']
                all_results_df.append(df)
all_results_df_sweep_initial_noise_scale = pd.concat(all_results_df)
# all_results_df_sweep_initial_noise_scale['regret'] = max_reward - all_results_df_sweep_initial_noise_scale['energy_mean']
all_results_df_sweep_initial_noise_scale['epoch'] = all_results_df_sweep_initial_noise_scale['epoch'] - 300
# Out:
# $0.270 \pm 0.053$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.023173    0.066826       0.000660
# 1    302     0.051140    0.094859       0.000937
# 2    304     0.153707    0.128653       0.001271
# 3    306     0.199424    0.119347       0.001179
# 4    308     0.227878    0.103908       0.001027
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.280 \pm 0.044$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.046246    0.088720       0.000877
# 1    302     0.107708    0.118279       0.001169
# 2    304     0.205598    0.113486       0.001121
# 3    306     0.239443    0.092282       0.000912
# 4    308     0.257314    0.074679       0.000738
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.285 \pm 0.038$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.068713    0.101215       0.001000
# 1    302     0.146139    0.118972       0.001176
# 2    304     0.231716    0.095850       0.000947
# 3    306     0.259888    0.070631       0.000698
# 4    308     0.273817    0.052321       0.000517
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.382 \pm 0.193$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.018745    0.071995       0.000711
# 1    302     0.038870    0.132677       0.001311
# 2    304     0.103113    0.201917       0.001995
# 3    306     0.203135    0.248122       0.002452
# 4    308     0.325701    0.253886       0.002509
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.647 \pm 0.139$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.037507    0.098185       0.000970
# 1    302     0.091386    0.191630       0.001894
# 2    304     0.263559    0.258007       0.002550
# 3    306     0.434767    0.227762       0.002251
# 4    308     0.558735    0.154897       0.001531
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.658 \pm 0.126$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.053430    0.114339       0.001130
# 1    302     0.138753    0.222256       0.002196
# 2    304     0.352747    0.250311       0.002474
# 3    306     0.536014    0.172632       0.001706
# 4    308     0.637787    0.080513       0.000796
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.613 \pm 0.158$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.034684    0.123870       0.001224
# 1    302     0.070004    0.172529       0.001705
# 2    304     0.146896    0.229209       0.002265
# 3    306     0.246384    0.255890       0.002529
# 4    308     0.348268    0.251483       0.002485
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.652 \pm 0.125$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.066841    0.164609       0.001627
# 1    302     0.152264    0.230908       0.002282
# 2    304     0.321972    0.254715       0.002517
# 3    306     0.472756    0.210873       0.002084
# 4    308     0.593654    0.125714       0.001242
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.664 \pm 0.109$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.102104    0.194413       0.001921
# 1    302     0.221308    0.252258       0.002493
# 2    304     0.415324    0.233577       0.002308
# 3    306     0.577908    0.138062       0.001364
# 4    308     0.649837    0.064709       0.000639
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.276 \pm 0.050$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.022419    0.065313       0.000645
# 1    302     0.081842    0.114269       0.001129
# 2    304     0.177898    0.127205       0.001257
# 3    306     0.207839    0.116680       0.001153
# 4    308     0.228206    0.104126       0.001029
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.402 \pm 0.194$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.045322    0.088322       0.000873
# 1    302     0.051814    0.140288       0.001386
# 2    304     0.147428    0.227844       0.002252
# 3    306     0.286637    0.256812       0.002538
# 4    308     0.433734    0.226085       0.002234
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.409 \pm 0.193$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.070017    0.101868       0.001007
# 1    302     0.160772    0.119131       0.001177
# 2    304     0.241209    0.090456       0.000894
# 3    306     0.260287    0.071739       0.000709
# 4    308     0.272838    0.055365       0.000547
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.611 \pm 0.163$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.018146    0.071728       0.000709
# 1    302     0.042536    0.136661       0.001351
# 2    304     0.112409    0.209071       0.002066
# 3    306     0.205653    0.249212       0.002463
# 4    308     0.300797    0.257417       0.002544
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.647 \pm 0.142$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.035018    0.096486       0.000953
# 1    302     0.090849    0.191266       0.001890
# 2    304     0.200114    0.246945       0.002440
# 3    306     0.344949    0.253245       0.002503
# 4    308     0.521757    0.182681       0.001805
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.659 \pm 0.127$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.056756    0.116506       0.001151
# 1    302     0.141756    0.224393       0.002217
# 2    304     0.339616    0.254385       0.002514
# 3    306     0.521358    0.182426       0.001803
# 4    308     0.631384    0.087879       0.000868
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.613 \pm 0.152$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.032099    0.119967       0.001186
# 1    302     0.082098    0.183614       0.001814
# 2    304     0.158435    0.233745       0.002310
# 3    306     0.264689    0.256107       0.002531
# 4    308     0.331008    0.252855       0.002499
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.652 \pm 0.127$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.064520    0.162001       0.001601
# 1    302     0.156681    0.231395       0.002287
# 2    304     0.305997    0.257364       0.002543
# 3    306     0.458592    0.215757       0.002132
# 4    308     0.572444    0.142592       0.001409
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.664 \pm 0.111$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.098222    0.190735       0.001885
# 1    302     0.220966    0.251772       0.002488
# 2    304     0.406477    0.237581       0.002348
# 3    306     0.537510    0.170739       0.001687
# 4    308     0.623391    0.096182       0.000950
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.471 \pm 0.224$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.023157    0.066668       0.000659
# 1    302     0.022350    0.067855       0.000671
# 2    304     0.029817    0.083921       0.000829
# 3    306     0.029879    0.099021       0.000979
# 4    308     0.035703    0.122369       0.001209
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.521 \pm 0.210$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.046924    0.088960       0.000879
# 1    302     0.116832    0.120574       0.001192
# 2    304     0.208572    0.112038       0.001107
# 3    306     0.236099    0.095080       0.000940
# 4    308     0.255224    0.077258       0.000763
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.531 \pm 0.207$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.067359    0.101183       0.001000
# 1    302     0.098876    0.189540       0.001873
# 2    304     0.277826    0.257456       0.002544
# 3    306     0.489438    0.200766       0.001984
# 4    308     0.618885    0.101572       0.001004
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.492 \pm 0.214$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.017493    0.070965       0.000701
# 1    302     0.043451    0.139391       0.001377
# 2    304     0.111181    0.206757       0.002043
# 3    306     0.199558    0.246520       0.002436
# 4    308     0.314358    0.256572       0.002535
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.646 \pm 0.138$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.037507    0.098185       0.000970
# 1    302     0.096840    0.196567       0.001942
# 2    304     0.243881    0.256474       0.002535
# 3    306     0.438835    0.225726       0.002231
# 4    308     0.576301    0.139438       0.001378
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.658 \pm 0.124$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.054220    0.115185       0.001138
# 1    302     0.141689    0.224355       0.002217
# 2    304     0.331118    0.255495       0.002525
# 3    306     0.529783    0.174567       0.001725
# 4    308     0.632612    0.085563       0.000846
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.600 \pm 0.161$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.034684    0.123870       0.001224
# 1    302     0.076898    0.179382       0.001773
# 2    304     0.160801    0.234697       0.002319
# 3    306     0.266165    0.257669       0.002546
# 4    308     0.368009    0.247122       0.002442
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.649 \pm 0.126$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.068360    0.166390       0.001644
# 1    302     0.155734    0.232359       0.002296
# 2    304     0.288612    0.257843       0.002548
# 3    306     0.420329    0.231430       0.002287
# 4    308     0.549058    0.161523       0.001596
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.661 \pm 0.111$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.102104    0.194413       0.001921
# 1    302     0.225348    0.253456       0.002505
# 2    304     0.408836    0.235746       0.002330
# 3    306     0.553263    0.157293       0.001554
# 4    308     0.640838    0.075950       0.000751
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_context('paper', font_scale=1.2)
for energy_fn_kwargs_l in all_results_df_sweep_initial_noise_scale['l'].unique():
    for initial_mean in all_results_df_sweep_initial_noise_scale['initial_mean'].unique():
        print(f"Initial mean: {initial_mean}, l: {energy_fn_kwargs_l}")
        df = all_results_df_sweep_initial_noise_scale[
            (all_results_df_sweep_initial_noise_scale['initial_mean'] == initial_mean) & 
            (all_results_df_sweep_initial_noise_scale['l'] == energy_fn_kwargs_l)
        ].reset_index(drop=True)
        # print(df.head().to_markdown())
        fig, ax = plt.subplots(1, 1, figsize=(3, 3))
        sns.lineplot(x='epoch', y='regret', data=df, hue='weights_transform_fn', ax=ax)
        h, l = ax.get_legend_handles_labels()
        ax.legend(h, ['identity', 'quadratic', 'softmax'], title='Weights')
        ax.set_yscale('log')
        ax.set_title(f'Initial mean: {initial_mean}, l: {energy_fn_kwargs_l}')
        plt.tight_layout()
        plt.savefig(f'regret_plot_log_energy_im{initial_mean}_l{l}.pdf', dpi=300)
# Out:
# Initial mean: 0.0, l: 0.1
# Initial mean: 1.0, l: 0.1
# Initial mean: 2.0, l: 0.1
# Initial mean: 0.0, l: 0.2
# Initial mean: 1.0, l: 0.2
# Initial mean: 2.0, l: 0.2
# Initial mean: 0.0, l: 0.3
# Initial mean: 1.0, l: 0.3
# Initial mean: 2.0, l: 0.3

# %%
def collect_toy_results(logdir):

    all_results_df = []
    # for weight_pre_transform_fn in ["substract_min", "standarize-relu", "standarize-substract_min"]:
    for weights_transform_fn in ["relu_normalize", "quad_relu_normalize", "softmax"]:
        for energy_fn_kwargs_l in [0.8, 1.0, 1.2, 1.4]:
            pattern = fr".*reweighting_rl.*energy_fn_kwargs_l_{energy_fn_kwargs_l}_{weights_transform_fn}.*$"
            df = load_full_results(pattern, logdir=logdir)
            if df is not None:
                # all_results_df.append({
                #     # 'weight_pre_transform_fn': weight_pre_transform_fn,
                #     'weights_transform_fn': weights_transform_fn,
                #     'mean': df['energy_mean'].mean(),
                #     'std': df['energy_mean'].std(),
                #     'se': df['energy_mean'].std() / np.sqrt(len(df)),
                #     'noise': 0.2,
                #     'energy_fn_kwargs_l': energy_fn_kwargs_l,
                #     'display': f"{df['energy_mean'].mean():.0f} $\pm$ {df['energy_mean'].std()/ np.sqrt(len(df)) :.0f}",
                # })
                # print(df.head())
                df['energy_fn_kwargs_l'] = energy_fn_kwargs_l
                df['weights_transform_fn'] = weights_transform_fn
                df['noise'] = 0.4
                all_results_df.append(df)
    all_results_df_sweep_initial_noise_scale = pd.concat(all_results_df)
    all_results_df_sweep_initial_noise_scale['regret'] = 0.7005724067912344 - all_results_df_sweep_initial_noise_scale['energy_mean']
    all_results_df_sweep_initial_noise_scale['epoch'] = all_results_df_sweep_initial_noise_scale['epoch'] - 300
    sns.set_context('paper', font_scale=1.2)
    fig, ax = plt.subplots(1, 1, figsize=(3, 3))
    for fn in all_results_df_sweep_initial_noise_scale['weights_transform_fn'].unique():
        unique_logdirs = all_results_df_sweep_initial_noise_scale.loc[
            all_results_df_sweep_initial_noise_scale['weights_transform_fn'] == fn, 'logdir'].nunique()
        print(f"Weights transform fn: {fn}, number of unique logdirs: {unique_logdirs}")
    sns.lineplot(x='epoch', y='regret', data=all_results_df_sweep_initial_noise_scale, errorbar='se', hue='weights_transform_fn', ax=ax)
    h, l = ax.get_legend_handles_labels()
    ax.legend(h, ['identity', 'quadratic', 'softmax'], title='Weights')
    ax.set_yscale('log')
    plt.tight_layout()
    plt.savefig(os.path.join(logdir, 'regret_plot.pdf'), dpi=300)
    
logdir = '/home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/sweep_energy_fn_kwargs_l_initial_mean_0.0'
collect_toy_results(logdir)
# Out:
# $0.294 \pm 0.009$
# $0.675 \pm 0.076$
# $0.674 \pm 0.072$
# $0.672 \pm 0.070$
# $0.681 \pm 0.072$
# $0.680 \pm 0.069$
# $0.678 \pm 0.069$
# $0.677 \pm 0.069$
# $0.373 \pm 0.086$
# $0.410 \pm 0.057$
# $0.361 \pm 0.078$
# $0.402 \pm 0.039$
# Weights transform fn: relu_normalize, number of unique logdirs: 4
# Weights transform fn: quad_relu_normalize, number of unique logdirs: 4
# Weights transform fn: softmax, number of unique logdirs: 4

# %%
logdir = '/home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/sweep_energy_fn_kwargs_l_initial_mean_0.0'
collect_toy_results(logdir)
# Out:
# $0.487 \pm 0.200$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.232562    0.079436       0.000785
# 1    301     0.243048    0.068773       0.000680
# 2    302     0.262174    0.050624       0.000500
# 3    303     0.276903    0.037396       0.000370
# 4    304     0.284033    0.028979       0.000286
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.678 \pm 0.073$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.230066    0.080683       0.000797
# 1    301     0.285628    0.128742       0.001272
# 2    302     0.405231    0.182273       0.001801
# 3    303     0.530560    0.157843       0.001560
# 4    304     0.623882    0.095817       0.000947
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.676 \pm 0.070$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.228273    0.080330       0.000794
# 1    301     0.268661    0.110165       0.001089
# 2    302     0.367187    0.172915       0.001709
# 3    303     0.503507    0.168532       0.001665
# 4    304     0.597218    0.118491       0.001171
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.674 \pm 0.069$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.231119    0.082149       0.000812
# 1    301     0.281919    0.125218       0.001237
# 2    302     0.383089    0.178248       0.001761
# 3    303     0.504272    0.166687       0.001647
# 4    304     0.601112    0.113656       0.001123
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.681 \pm 0.072$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.231419    0.079723       0.000788
# 1    301     0.282162    0.125141       0.001237
# 2    302     0.375375    0.177415       0.001753
# 3    303     0.513710    0.166821       0.001649
# 4    304     0.598893    0.117183       0.001158
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.680 \pm 0.069$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.230066    0.080683       0.000797
# 1    301     0.285628    0.128742       0.001272
# 2    302     0.405231    0.182273       0.001801
# 3    303     0.530560    0.157843       0.001560
# 4    304     0.623882    0.095817       0.000947
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.678 \pm 0.069$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.231664    0.079870       0.000789
# 1    301     0.286621    0.128759       0.001272
# 2    302     0.400497    0.181492       0.001794
# 3    303     0.526286    0.159235       0.001574
# 4    304     0.615898    0.101643       0.001004
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.677 \pm 0.069$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.230350    0.079519       0.000786
# 1    301     0.288371    0.131557       0.001300
# 2    302     0.398331    0.181142       0.001790
# 3    303     0.529790    0.158763       0.001569
# 4    304     0.620591    0.098617       0.000975
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.373 \pm 0.086$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.230169    0.079670       0.000787
# 1    301     0.225103    0.082709       0.000817
# 2    302     0.218307    0.085743       0.000847
# 3    303     0.213553    0.088525       0.000875
# 4    304     0.209956    0.089414       0.000884
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.410 \pm 0.057$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.230529    0.081375       0.000804
# 1    301     0.237941    0.080125       0.000792
# 2    302     0.246010    0.081818       0.000809
# 3    303     0.254497    0.089520       0.000885
# 4    304     0.261835    0.097786       0.000966
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.361 \pm 0.078$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.232023    0.080961       0.000800
# 1    301     0.228822    0.081457       0.000805
# 2    302     0.224400    0.082070       0.000811
# 3    303     0.222013    0.083075       0.000821
# 4    304     0.220059    0.083348       0.000824
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...
# $0.402 \pm 0.039$
#    epoch  energy_mean  energy_std  energy_stderr  \
# 0    300     0.231467    0.080908       0.000800
# 1    301     0.242424    0.083063       0.000821
# 2    302     0.258447    0.098622       0.000975
# 3    303     0.279479    0.121083       0.001197
# 4    304     0.303667    0.142240       0.001406
#
#                                               logdir
# 0  /home/naliseas-workstation/Documents/haitong/d...
# 1  /home/naliseas-workstation/Documents/haitong/d...
# 2  /home/naliseas-workstation/Documents/haitong/d...
# 3  /home/naliseas-workstation/Documents/haitong/d...
# 4  /home/naliseas-workstation/Documents/haitong/d...

# %%
logdir = '/home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/sweep_energy_fn_kwargs_l_initial_mean_0.0_fixed_softmax'
collect_toy_results(logdir)
# Out:
# $0.682 \pm 0.049$
# $0.681 \pm 0.044$
# $0.679 \pm 0.041$
# $0.677 \pm 0.077$
# $0.685 \pm 0.044$
# $0.683 \pm 0.043$
# $0.681 \pm 0.045$
# $0.679 \pm 0.043$
# $0.676 \pm 0.042$
# Weights transform fn: relu_normalize, number of unique logdirs: 3
# Weights transform fn: quad_relu_normalize, number of unique logdirs: 3
# Weights transform fn: softmax, number of unique logdirs: 3

# %%
logdir = '/home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/sweep_energy_fn_kwargs_l_initial_mean_1.0_fixed_softmax'
collect_toy_results(logdir)
# Out:
# $0.682 \pm 0.049$
# $0.681 \pm 0.044$
# $0.679 \pm 0.041$
# $0.687 \pm 0.042$
# $0.685 \pm 0.044$
# $0.683 \pm 0.043$
# $0.681 \pm 0.045$
# $0.679 \pm 0.043$
# $0.676 \pm 0.042$
# Weights transform fn: relu_normalize, number of unique logdirs: 3
# Weights transform fn: quad_relu_normalize, number of unique logdirs: 3
# Weights transform fn: softmax, number of unique logdirs: 3

# %%
logdir = '/home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/sweep_energy_fn_kwargs_l_initial_mean_2.0_fixed_softmax'
collect_toy_results(logdir)
# Out:
# $0.682 \pm 0.049$
# $0.681 \pm 0.044$
# $0.679 \pm 0.041$
# $0.687 \pm 0.042$
# $0.684 \pm 0.044$
# $0.683 \pm 0.043$
# $0.681 \pm 0.045$
# $0.678 \pm 0.043$
# $0.676 \pm 0.042$
# Weights transform fn: relu_normalize, number of unique logdirs: 4
# Weights transform fn: quad_relu_normalize, number of unique logdirs: 4
# Weights transform fn: softmax, number of unique logdirs: 4

# %%
def collect_toy_results(logdir):

    all_results_df = []
    # for weight_pre_transform_fn in ["substract_min", "standarize-relu", "standarize-substract_min"]:
    for weights_transform_fn in ["relu_normalize", "quad_relu_normalize", "softmax"]:
        # for energy_fn_kwargs_l in [0.8, 1.0, 1.2, 1.4]:
        pattern = fr".*reweighting_rl.*energy_fn_kwargs_l__{weights_transform_fn}.*$"
        df = load_full_results(pattern, logdir=logdir)
        if df is not None:
            # all_results_df.append({
            #     # 'weight_pre_transform_fn': weight_pre_transform_fn,
            #     'weights_transform_fn': weights_transform_fn,
            #     'mean': df['energy_mean'].mean(),
            #     'std': df['energy_mean'].std(),
            #     'se': df['energy_mean'].std() / np.sqrt(len(df)),
            #     'noise': 0.2,
            #     'energy_fn_kwargs_l': energy_fn_kwargs_l,
            #     'display': f"{df['energy_mean'].mean():.0f} $\pm$ {df['energy_mean'].std()/ np.sqrt(len(df)) :.0f}",
            # })
            # print(df.head())
            df['energy_fn_kwargs_l'] = energy_fn_kwargs_l
            df['weights_transform_fn'] = weights_transform_fn
            df['noise'] = 0.4
            # EMA smoothing for energy_mean for each logdir
            # if 'logdir' in df.columns:
            #     ema_alpha = 0.2
            #     df = df.sort_values(['logdir', 'epoch'])
            #     df['energy_mean_smooth'] = df.groupby('logdir')['energy_mean'].transform(
            #         lambda x: x.ewm(alpha=ema_alpha, adjust=False).mean()
            #     )
            all_results_df.append(df)
    all_results_df_sweep_initial_noise_scale = pd.concat(all_results_df)
    all_results_df_sweep_initial_noise_scale['regret'] = 0.7005724067912344 - all_results_df_sweep_initial_noise_scale['energy_mean']
    all_results_df_sweep_initial_noise_scale['epoch'] = all_results_df_sweep_initial_noise_scale['epoch'] - 300
    sns.set_context('paper', font_scale=1.2)
    fig, ax = plt.subplots(1, 1, figsize=(3, 3))
    for fn in all_results_df_sweep_initial_noise_scale['weights_transform_fn'].unique():
        unique_logdirs = all_results_df_sweep_initial_noise_scale.loc[
            all_results_df_sweep_initial_noise_scale['weights_transform_fn'] == fn, 'logdir'].nunique()
        print(f"Weights transform fn: {fn}, number of unique logdirs: {unique_logdirs}")
    sns.lineplot(x='epoch', y='regret', data=all_results_df_sweep_initial_noise_scale, errorbar='se', hue='weights_transform_fn', ax=ax)
    h, l = ax.get_legend_handles_labels()
    ax.legend(h, ['Relu_linear', 'Relu_quadratic', 'softmax'], title='Weights')
    ax.set_yscale('log')
    plt.tight_layout()
    plt.savefig(os.path.join(logdir, 'regret_plot.pdf'), dpi=300)
    
logdir = '/home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/sweep_energy_fn_kwargs_l_initial_mean_1.0_fixed_softmax_v2'
collect_toy_results(logdir)
logdir = '/home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/sweep_energy_fn_kwargs_l_initial_mean_0.0_fixed_softmax_v2'
collect_toy_results(logdir)
logdir = '/home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/sweep_energy_fn_kwargs_l_initial_mean_1.0_fixed_softmax_v2'
collect_toy_results(logdir)
# Out:
# $0.690 \pm 0.030$
# $0.690 \pm 0.046$
# $0.691 \pm 0.031$
# Weights transform fn: relu_normalize, number of unique logdirs: 3
# Weights transform fn: quad_relu_normalize, number of unique logdirs: 3
# Weights transform fn: softmax, number of unique logdirs: 3
# $0.690 \pm 0.030$
# $0.693 \pm 0.031$
# $0.691 \pm 0.031$
# Weights transform fn: relu_normalize, number of unique logdirs: 3
# Weights transform fn: quad_relu_normalize, number of unique logdirs: 3
# Weights transform fn: softmax, number of unique logdirs: 3
# $0.690 \pm 0.030$
# $0.690 \pm 0.046$
# $0.691 \pm 0.031$
# Weights transform fn: relu_normalize, number of unique logdirs: 3
# Weights transform fn: quad_relu_normalize, number of unique logdirs: 3
# Weights transform fn: softmax, number of unique logdirs: 3

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 logdir = '/home/naliseas-workstation/Documents/haitong/diffusion-model-hallucination/chkpts/sweep_energy_fn_kwargs_l_initial_mean_2.0_fixed_softmax_v2'
# ----> 2 collect_toy_results(logdir)
#
# Cell In[37], line 25, in collect_toy_results(logdir)
#      23             df['noise'] = 0.4
#      24             all_results_df.append(df)
# ---> 25 all_results_df_sweep_initial_noise_scale = pd.concat(all_results_df)
#      26 all_results_df_sweep_initial_noise_scale['regret'] = 0.7005724067912344 - all_results_df_sweep_initial_noise_scale['energy_mean']
#      27 all_results_df_sweep_initial_noise_scale['epoch'] = all_results_df_sweep_initial_noise_scale['epoch'] - 300
#
# File ~/anaconda3/envs/haitong_botorch/lib/python3.9/site-packages/pandas/core/reshape/concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#     383     ignore_index=ignore_index,
#     384     join=join,
#     385     keys=keys,
#     386     levels=levels,
#     387     names=names,
#     388     verify_integrity=verify_integrity,
#     389     copy=copy,
#     390     sort=sort,
#     391 )
#     393 return op.get_result()
#
# File ~/anaconda3/envs/haitong_botorch/lib/python3.9/site-packages/pandas/core/reshape/concat.py:443, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     440 self.verify_integrity = verify_integrity
#     441 self.copy = copy
# --> 443 objs, keys = self._clean_keys_and_objs(objs, keys)
#     445 # figure out what our result ndim is going to be
#     446 ndims = self._get_ndims(objs)
#
# File ~/anaconda3/envs/haitong_botorch/lib/python3.9/site-packages/pandas/core/reshape/concat.py:505, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     502     objs_list = list(objs)
#     504 if len(objs_list) == 0:
# --> 505     raise ValueError("No objects to concatenate")
#     507 if keys is None:
#     508     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate
